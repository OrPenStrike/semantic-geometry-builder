# %% [markdown]
# # Sim Flip Chip Distance - Route A - No Inset
#
# This notebook validates the official tutorial asset and stack coverage only. Builder execution is disabled for this fixture until high-count bump contact and lumped-port sheet planning are implemented.
#
# Inset breakpoints: `0, 50 nm, 100 nm, 200 nm, 500 nm, 1 um`.
# Sidewall inset bands that would degenerate are skipped by the planner.

# %%
from pathlib import Path
import json

import gdstk
from semantic_geometry_builder import (
    SemanticGeometryBuilder,
    build_gds_stack_geometry_input,
)

GEOMETRY_ID = 'sim_flip_chip_distance'
ROUTE = 'A'
MODE = 'no_inset'
BUILD_SUPPORTED = True
INSET_BREAKPOINTS_UM = [0.0, 0.05, 0.1, 0.2, 0.5, 1.0]
TOP_CELL_NAME = 'sim_flip_chip_distance_CCW9900_CCH9900_QCW7500_QCH7500__8b338b3b'

ROOT = Path.cwd()
while not (ROOT / "pyproject.toml").is_file():
    if ROOT.parent == ROOT:
        raise RuntimeError("Could not locate repository root")
    ROOT = ROOT.parent

ASSET_DIR = ROOT / "tutorials" / "assets"
RUN_FOLDER = ROOT / "tutorials" / "runs" / MODE / GEOMETRY_ID / f"route_{ROUTE.lower()}"
GDS_FILE = ASSET_DIR / f"{GEOMETRY_ID}.gds"
STACK_FILE = ASSET_DIR / f"{GEOMETRY_ID}.stack.json"
METADATA_OVERRIDE = {"inset_routes": []}

build_input = build_gds_stack_geometry_input(
    gds_file=GDS_FILE,
    stack_file=STACK_FILE,
    top_cell_name=TOP_CELL_NAME,
    metadata=METADATA_OVERRIDE,
)
print("polygons:", len(build_input.polygons))
print("entities:", len(build_input.entities))
print("inset routes:", build_input.metadata.get("inset_routes"))
# Out:
# polygons: 35
# entities: 39
# inset routes: []

# %%
stack = json.loads(STACK_FILE.read_text())
if TOP_CELL_NAME is not None:
    cell = next(c for c in gdstk.read_gds(str(GDS_FILE)).cells if c.name == TOP_CELL_NAME)
    gds_layers = {(int(p.layer), int(p.datatype)) for p in cell.get_polygons(apply_repetitions=True)}
    layer_records = {(int(r["layer"]), int(r["datatype"])) for r in stack.get("layers", [])}
    ignored = {(int(r["layer"]), int(r["datatype"])) for r in stack["metadata"].get("ignored_layout_layers", [])}
    deferred = {(int(r["layer"]), int(r["datatype"])) for r in stack["metadata"].get("deferred_high_count_layers", [])}
    print("unclassified layers:", sorted(gds_layers - layer_records - ignored - deferred))
    print("ignored layers:", sorted(ignored))
    print("deferred layers:", sorted(deferred))
    assert (40, 1) in ignored, "Under Bump layer must stay ignored"
    assert (40, 1) not in deferred, "Under Bump layer must not be deferred for simulation"
    assert (202, 1) in ignored, "Palace lumped-port sheet layer is not implemented yet"
# Out:
# unclassified layers: []
# ignored layers: [(1, 1), (2, 1), (40, 1), (202, 1)]
# deferred layers: [(40, 0)]

# %%
if not BUILD_SUPPORTED:
    print("Builder intentionally not run for this fixture yet.")
else:
    groups = SemanticGeometryBuilder().build(
        build_input,
        route=ROUTE,
        run_folder=RUN_FOLDER,
    )
    xao_path = RUN_FOLDER / "geometry" / f"semantic_geometry_route_{ROUTE.lower()}.xao"
    print("XAO:", xao_path)
    print("groups:", len(groups))
    for group in groups:
        print(group.dimension, group.physical_name, len(group.entity_tags))
    assert xao_path.is_file()
    assert not list(RUN_FOLDER.rglob("*.msh"))
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# XAO: /Users/arfiligol/Github/SCQ_Design/semantic_geometry_builder/tutorials/runs/no_inset/sim_flip_chip_distance/route_a/geometry/semantic_geometry_route_a.xao
# groups: 73
# 3 D0_To_D1_Air 1
# 3 Outer_Air 1
# 3 D0_Substrate 1
# 3 D1_Substrate 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0000 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0001 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0002 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0003 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0004 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0005 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0006 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0007 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0008 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0009 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0010 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0011 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0012 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0013 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0014 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0015 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0016 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0017 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0018 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0019 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0020 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0021 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0022 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0023 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0024 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0025 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0026 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0027 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0028 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0029 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0030 1
# 2 SA__D0_Substrate__D0_To_D1_Air__0031 1
# 2 SA__D1_Substrate__D0_To_D1_Air__0032 1
# 2 SA__D1_Substrate__Outer_Air__0033 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0000__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0001__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0002__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0003__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0004__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0005__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0006__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0007__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0008__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0009__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0010__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0011__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0012__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0013__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0014__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0015__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0016__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0017__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0018__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0019__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0020__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0021__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0022__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0023__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0024__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0025__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0026__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0027__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0028__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0029__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0030__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D0_TOP_M1_Unassigned_0031__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D1_BOTTOM_M1_Resonator__D0_To_D1_Air__D1_Substrate__0000 1
# 2 MS_MA_SA__D0_TOP_M1_GROUND__D0_Substrate__D0_To_D1_Air__0000 1
# 2 MS_MA_SA__D1_BOTTOM_M1_GROUND__D0_To_D1_Air__D1_Substrate__0000 1
