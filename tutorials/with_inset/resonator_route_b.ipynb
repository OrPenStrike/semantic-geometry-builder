# %% [markdown]
# # Resonator - Route B - With Inset
#
# This notebook builds one route XAO file and prints final physical groups.
#
# Inset breakpoints: `0, 50 nm, 100 nm, 200 nm, 500 nm, 1 um`.
# Sidewall inset bands that would degenerate are skipped by the planner.

# %%
from pathlib import Path
import json

import gdstk
from semantic_geometry_builder import (
    SemanticGeometryBuilder,
    build_gds_stack_geometry_input,
)

GEOMETRY_ID = 'resonator'
ROUTE = 'B'
MODE = 'with_inset'
BUILD_SUPPORTED = True
INSET_BREAKPOINTS_UM = [0.0, 0.05, 0.1, 0.2, 0.5, 1.0]
TOP_CELL_NAME = None

ROOT = Path.cwd()
while not (ROOT / "pyproject.toml").is_file():
    if ROOT.parent == ROOT:
        raise RuntimeError("Could not locate repository root")
    ROOT = ROOT.parent

ASSET_DIR = ROOT / "tutorials" / "assets"
RUN_FOLDER = ROOT / "tutorials" / "runs" / MODE / GEOMETRY_ID / f"route_{ROUTE.lower()}"
GDS_FILE = ASSET_DIR / f"{GEOMETRY_ID}.gds"
STACK_FILE = ASSET_DIR / f"{GEOMETRY_ID}.stack.json"
METADATA_OVERRIDE = {"inset_breakpoints_um": INSET_BREAKPOINTS_UM, "inset_routes": [ROUTE]}

build_input = build_gds_stack_geometry_input(
    gds_file=GDS_FILE,
    stack_file=STACK_FILE,
    top_cell_name=TOP_CELL_NAME,
    metadata=METADATA_OVERRIDE,
)
print("polygons:", len(build_input.polygons))
print("entities:", len(build_input.entities))
print("inset routes:", build_input.metadata.get("inset_routes"))
# Out:
# polygons: 3
# entities: 5
# inset routes: ['B']

# %%
if not BUILD_SUPPORTED:
    print("Builder intentionally not run for this fixture yet.")
else:
    groups = SemanticGeometryBuilder().build(
        build_input,
        route=ROUTE,
        run_folder=RUN_FOLDER,
    )
    xao_path = RUN_FOLDER / "geometry" / f"semantic_geometry_route_{ROUTE.lower()}.xao"
    print("XAO:", xao_path)
    print("groups:", len(groups))
    for group in groups:
        print(group.dimension, group.physical_name, len(group.entity_tags))
    assert xao_path.is_file()
    assert not list(RUN_FOLDER.rglob("*.msh"))
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# XAO: /Users/arfiligol/Github/SCQ_Design/semantic_geometry_builder/tutorials/runs/with_inset/resonator/route_b/geometry/semantic_geometry_route_b.xao
# groups: 36
# 3 AIR 1
# 3 D0_Substrate 1
# 2 SA__D0_Substrate__AIR__0000__RING_0NM_50NM 1
# 2 SA__D0_Substrate__AIR__0000__RING_50NM_100NM 1
# 2 SA__D0_Substrate__AIR__0000__RING_100NM_200NM 1
# 2 SA__D0_Substrate__AIR__0000__RING_200NM_500NM 1
# 2 SA__D0_Substrate__AIR__0000__RING_500NM_1UM 1
# 2 SA__D0_Substrate__AIR__0000__CORE_AFTER_1UM 1
# 2 MA__D0_TOP_M1_Resonator__AIR__TOP__RING_0NM_50NM 1
# 2 MA__D0_TOP_M1_Resonator__AIR__TOP__RING_50NM_100NM 1
# 2 MA__D0_TOP_M1_Resonator__AIR__TOP__RING_100NM_200NM 1
# 2 MA__D0_TOP_M1_Resonator__AIR__TOP__RING_200NM_500NM 1
# 2 MA__D0_TOP_M1_Resonator__AIR__TOP__RING_500NM_1UM 1
# 2 MA__D0_TOP_M1_Resonator__AIR__TOP__CORE_AFTER_1UM 1
# 2 MS__D0_TOP_M1_Resonator__D0_Substrate__BOTTOM__RING_0NM_50NM 1
# 2 MS__D0_TOP_M1_Resonator__D0_Substrate__BOTTOM__RING_50NM_100NM 1
# 2 MS__D0_TOP_M1_Resonator__D0_Substrate__BOTTOM__RING_100NM_200NM 1
# 2 MS__D0_TOP_M1_Resonator__D0_Substrate__BOTTOM__RING_200NM_500NM 1
# 2 MS__D0_TOP_M1_Resonator__D0_Substrate__BOTTOM__RING_500NM_1UM 1
# 2 MS__D0_TOP_M1_Resonator__D0_Substrate__BOTTOM__CORE_AFTER_1UM 1
# 2 MA__D0_TOP_M1_Resonator__AIR__SIDEWALL__RING_0NM_50NM 214
# 2 MA__D0_TOP_M1_Resonator__AIR__SIDEWALL__CORE_AFTER_50NM 107
# 2 MA__D0_TOP_M1_GROUND__AIR__TOP__RING_0NM_50NM 2
# 2 MA__D0_TOP_M1_GROUND__AIR__TOP__RING_50NM_100NM 2
# 2 MA__D0_TOP_M1_GROUND__AIR__TOP__RING_100NM_200NM 2
# 2 MA__D0_TOP_M1_GROUND__AIR__TOP__RING_200NM_500NM 2
# 2 MA__D0_TOP_M1_GROUND__AIR__TOP__RING_500NM_1UM 2
# 2 MA__D0_TOP_M1_GROUND__AIR__TOP__CORE_AFTER_1UM 1
# 2 MS__D0_TOP_M1_GROUND__D0_Substrate__BOTTOM__RING_0NM_50NM 2
# 2 MS__D0_TOP_M1_GROUND__D0_Substrate__BOTTOM__RING_50NM_100NM 2
# 2 MS__D0_TOP_M1_GROUND__D0_Substrate__BOTTOM__RING_100NM_200NM 2
# 2 MS__D0_TOP_M1_GROUND__D0_Substrate__BOTTOM__RING_200NM_500NM 2
# 2 MS__D0_TOP_M1_GROUND__D0_Substrate__BOTTOM__RING_500NM_1UM 2
# 2 MS__D0_TOP_M1_GROUND__D0_Substrate__BOTTOM__CORE_AFTER_1UM 1
# 2 MA__D0_TOP_M1_GROUND__AIR__SIDEWALL__RING_0NM_50NM 218
# 2 MA__D0_TOP_M1_GROUND__AIR__SIDEWALL__CORE_AFTER_50NM 109
